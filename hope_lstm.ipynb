# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer

import string
import re

from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC

from sklearn.metrics import accuracy_score
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import metrics

from time import time

import warnings
warnings.filterwarnings("ignore")

# %%
dftrain=pd.read_csv("/content/drive/MyDrive/hope/english dATA SET/Task 2 Training set (English).csv")

# %%
dftrain
# Out:
#                                                    text    binary  \
# 0     #USER# #USER# I'm really liking this project, ...      Hope
# 1     #USER# Oh shit really? I would hope they'd she...      Hope
# 2     #USER# Good morning, Bud! 🥰 Another good decis...      Hope
# 3     i aspire to have the level of delusion to beli...      Hope
# 4     #USER# #USER# Projects are continuously attack...  Not Hope
# ...                                                 ...       ...
# 6187  🌟: But, it was a great depiction of the main c...  Not Hope
# 6188  Because it's brave to outright misappropriate ...  Not Hope
# 6189  #USER# They got this one wrong. I'm a devout, ...  Not Hope
# 6190  #USER# #USER# Not even close. Myself as many o...  Not Hope
# 6191  #USER# 💯 agree mate. Started doing this a few ...  Not Hope
#
#             multiclass    id
# 0       Realistic Hope  5820
# 1     Generalized Hope  4061
# 2     Generalized Hope  1621
# 3     Unrealistic Hope  1754
# 4             Not Hope   401
# ...                ...   ...
# 6187          Not Hope  3889
# 6188          Not Hope  3945
# 6189          Not Hope  6736
# 6190          Not Hope  4845
# 6191          Not Hope  4753
#
# [6192 rows x 4 columns]

# %%
dfvalid=pd.read_csv("/content/drive/MyDrive/hope/english dATA SET/val.csv")

# %%
dftest=pd.read_csv("/content/drive/MyDrive/hope/english dATA SET/test - no_label.csv")

# %%
import pandas as pd

dftrain = dftrain[['id', 'text', 'binary']]
dftrain
# Out:
#         id                                               text    binary
# 0     5820  #USER# #USER# I'm really liking this project, ...      Hope
# 1     4061  #USER# Oh shit really? I would hope they'd she...      Hope
# 2     1621  #USER# Good morning, Bud! 🥰 Another good decis...      Hope
# 3     1754  i aspire to have the level of delusion to beli...      Hope
# 4      401  #USER# #USER# Projects are continuously attack...  Not Hope
# ...    ...                                                ...       ...
# 6187  3889  🌟: But, it was a great depiction of the main c...  Not Hope
# 6188  3945  Because it's brave to outright misappropriate ...  Not Hope
# 6189  6736  #USER# They got this one wrong. I'm a devout, ...  Not Hope
# 6190  4845  #USER# #USER# Not even close. Myself as many o...  Not Hope
# 6191  4753  #USER# 💯 agree mate. Started doing this a few ...  Not Hope
#
# [6192 rows x 3 columns]

# %%
import pandas as pd

dfvalid = dfvalid[['id', 'text', 'binary']]
dfvalid
# Out:
#         id                                               text    binary
# 0     3229  She should be proving herself to you. Successf...  Not Hope
# 1       36  The female desire for tall men comes from thei...  Not Hope
# 2      136  “The inside of the old Camaro smelled like asp...  Not Hope
# 3     1970  The villa must be boring during the day if the...  Not Hope
# 4     1569  #USER# #USER# #USER# #USER# #USER# #USER# #USE...      Hope
# ...    ...                                                ...       ...
# 1027   612  #USER# #USER# #USER# #USER# Going backwards to...  Not Hope
# 1028  7562  #USER# Wouldn’t want to own any of the discuss...      Hope
# 1029  6467  #USER# #USER# I wouldn't be surprised if Roone...      Hope
# 1030  1816  #USER# It will be a honorable thing if u can r...  Not Hope
# 1031  5040  Jimmy and Tommy being in Korea really feels a ...      Hope
#
# [1032 rows x 3 columns]

# %%
import pandas as pd
import re

def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = text.encode('ascii', 'ignore').decode('ascii')
    text = text.lower()

    return text

dftrain['text'] = dftrain['text'].apply(preprocess_text)
dfvalid['text'] = dfvalid['text'].apply(preprocess_text)
dftest['text'] = dftest['text'].apply(preprocess_text)

# %%
dftrain
# Out:
#         id                                               text    binary
# 0     5820  user user im really liking this project lets w...      Hope
# 1     4061  user oh shit really i would hope theyd shed so...      Hope
# 2     1621  user good morning bud  another good decision f...      Hope
# 3     1754  i aspire to have the level of delusion to beli...      Hope
# 4      401  user user projects are continuously attacked b...  Not Hope
# ...    ...                                                ...       ...
# 6187  3889   but it was a great depiction of the main char...  Not Hope
# 6188  3945  because its brave to outright misappropriate f...  Not Hope
# 6189  6736  user they got this one wrong im a devout pract...  Not Hope
# 6190  4845  user user not even close myself as many others...  Not Hope
# 6191  4753  user  agree mate started doing this a few mont...  Not Hope
#
# [6192 rows x 3 columns]

# %%
dftest
# Out:
#                                                    text    id
# 0     volatility term structure is trading back in c...  1120
# 1     user very sad last night  we were up two games...  4300
# 2     my mind is continuously looping through vacati...  1008
# 3     user i used to go around with my one armed gla...  8003
# 4     user do we know the episode count for this ser...  3449
# ...                                                 ...   ...
# 1027  user user user still doesnt tell me anything h...  6038
# 1028  user ahh okay i get it thanks for the info i r...  4592
# 1029  user user user im once again hopeful for drago...  1012
# 1030  user im not so theologically illiterate that i...  5004
# 1031  an url miracle \n\nhopeful all seeing that nd ...  1426
#
# [1032 rows x 2 columns]

# %%
dfvalid
# Out:
#         id                                               text    binary
# 0     3229  she should be proving herself to you successfu...  Not Hope
# 1       36  the female desire for tall men comes from thei...  Not Hope
# 2      136  the inside of the old camaro smelled like asph...  Not Hope
# 3     1970  the villa must be boring during the day if the...  Not Hope
# 4     1569  user user user user user user user user user u...      Hope
# ...    ...                                                ...       ...
# 1027   612  user user user user going backwards to this  i...  Not Hope
# 1028  7562  user wouldnt want to own any of the discussed ...      Hope
# 1029  6467  user user i wouldnt be surprised if rooney pai...      Hope
# 1030  1816  user it will be a honorable thing if u can rep...  Not Hope
# 1031  5040  jimmy and tommy being in korea really feels a ...      Hope
#
# [1032 rows x 3 columns]

# %%
import pandas as pd

dftrain.rename(columns={'binary': 'label'}, inplace=True)
dfvalid.rename(columns={'binary': 'label'}, inplace=True)

dftrain['label'] = dftrain['label'].replace({'Not Hope': 0, 'Hope': 1})
dfvalid['label'] = dfvalid['label'].replace({'Not Hope': 0, 'Hope': 1})

# %%
docs = list(dftrain['text'])
tfidf_vectorizer = TfidfVectorizer(use_idf=True, max_features = 200)
tfidf_vectorizer_vectors = tfidf_vectorizer.fit_transform(docs)
docs = tfidf_vectorizer_vectors.toarray()

# %%
X_train = docs
y_train = dftrain['label']
print(X_train.shape, y_train.shape)
# Out:
# (6192, 200) (6192,)

# %%
docsval = list(dfvalid['text'])
tfidf_vectorizer_val = TfidfVectorizer(use_idf=True, max_features = 200)
tfidf_vectorizer_vectors_val = tfidf_vectorizer_val.fit_transform(docsval)
docsval = tfidf_vectorizer_vectors_val.toarray()

# %%
X_val = docsval
y_valid = dfvalid['label']
print(X_val.shape, y_valid.shape)
# Out:
# (1032, 200) (1032,)

# %%
docstest = list(dftest['text'])
tfidf_vectorizer_test = TfidfVectorizer(use_idf=True, max_features = 200)
tfidf_vectorizer_vectors_test = tfidf_vectorizer_test.fit_transform(docstest)
docstest = tfidf_vectorizer_vectors_test.toarray()

# %%
X_test = docstest
#y_valid = dfvalid['label']
print(X_test.shape)
      #, y_valid.shape)
# Out:
# (1032, 200)

# %%
from sklearn.ensemble import RandomForestClassifier

text_classifier = RandomForestClassifier(n_estimators=200, random_state=0)
text_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200, random_state=0)

# %%
y_pred = text_classifier.predict(X_test)

# %%
print(len(y_valid), len(y_pred))
# Out:
# 1032 1032

# %%
from sklearn.metrics import classification_report
report = classification_report(y_valid, y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.47      0.49       502
#            1       0.52      0.55      0.54       530
#
#     accuracy                           0.51      1032
#    macro avg       0.51      0.51      0.51      1032
# weighted avg       0.51      0.51      0.51      1032

# %%
import pandas as pd

y_pred= ['hope' if pred == 1 else 'non hope' for pred in y_pred]
if 'PID' in df.index:
    predictions_df = pd.DataFrame({'ID': df.loc[y_test.index, 'PID'].values, 'category': y_pred})
else:
    predictions_df = pd.DataFrame({'ID': range(len(y_pred_test)), 'category': y_pred})

predictions_df.to_csv('predictions1.csv', index=False)

print("Predictions saved to 'predictions1.csv'")
# Out:
# Predictions saved to 'predictions1.csv'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC

tfidf_vectorizer = TfidfVectorizer()
svc_classifier = SVC(kernel='linear', random_state=0)
svc_classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred_test = svc_classifier.predict(X_test)

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_valid, y_pred_test))

print("\nClassification Report:")
print(classification_report(y_valid, y_pred_test))

accuracy = accuracy_score(y_valid, y_pred_test)
print("\nAccuracy Score:", accuracy)
# Out:
# Confusion Matrix:
# [[212 290]
#  [223 307]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.42      0.45       502
#            1       0.51      0.58      0.54       530
#
#     accuracy                           0.50      1032
#    macro avg       0.50      0.50      0.50      1032
# weighted avg       0.50      0.50      0.50      1032
#
#
# Accuracy Score: 0.502906976744186

# %%
import pandas as pd

y_pred_test = ['hope' if pred == 1 else 'non hope' for pred in y_pred]
if 'PID' in df.index:
    predictions_df = pd.DataFrame({'ID': df.loc[y_test.index, 'PID'].values, 'category': y_pred_test})
else:
    predictions_df = pd.DataFrame({'ID': range(len(y_pred_test)), 'category': y_pred_test})
predictions_df.to_csv('predictions11.csv', index=False)

print("Predictions saved to 'predictions11.csv'")
# Out:
# Predictions saved to 'predictions11.csv'

# %%
from sklearn.metrics import classification_report
report = classification_report(y_val, y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.63      0.69       502
#            1       0.70      0.80      0.75       530
#
#     accuracy                           0.72      1032
#    macro avg       0.73      0.72      0.72      1032
# weighted avg       0.72      0.72      0.72      1032

# %%
predictions = svc_classifier.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e4e78f06b24e> in <cell line: 1>()
# ----> 1 predictions = svc_classifier.predict(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     818             y = np.argmax(self.decision_function(X), axis=1)
#     819         else:
# --> 820             y = super().predict(X)
#     821         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     822
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in predict(self, X)
#     431             The predicted values.
#     432         """
# --> 433         X = self._validate_for_predict(X)
#     434         predict = self._sparse_predict if self._sparse else self._dense_predict
#     435         return predict(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in _validate_for_predict(self, X)
#     611
#     612         if not callable(self.kernel):
# --> 613             X = self._validate_data(
#     614                 X,
#     615                 accept_sparse="csr",
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563             raise ValueError("Validation should be done on X, y or both.")
#     564         elif not no_val_X and no_val_y:
# --> 565             X = check_array(X, input_name="X", **check_params)
#     566             out = X
#     567         elif no_val_X and not no_val_y:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877                     array = xp.astype(array, dtype, copy=False)
#     878                 else:
# --> 879                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880             except ComplexWarning as complex_warning:
#     881                 raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_array_api.py in _asarray_with_order(array, dtype, order, copy, xp)
#     183     if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184         # Use NumPy API to support order
# --> 185         array = numpy.asarray(array, order=order, dtype=dtype)
#     186         return xp.asarray(array, copy=copy)
#     187     else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     915         """
#     916         values = self._values
# --> 917         arr = np.asarray(values, dtype=dtype)
#     918         if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#     919             arr = arr.view()
#
# ValueError: could not convert string to float: 'she should be proving herself to you successful interactions is when shes in pursuit \n\ni never seen a select dude prove himself to a woman they show interest and if she doesnt reciprocate then they move on so why are you sticking around hoping she changes her mind'

# %%
X_train=dftrain["text"]
y_train=dftrain["label"]

X_test=dfvalid["text"]
y_test=dfvalid["label"]

# %%
import pandas as pd
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

max_words = 10000
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(X_train)

X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

max_sequence_length = 100
X_train_pad = pad_sequences(X_train_seq, maxlen=max_sequence_length)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_sequence_length)

# Define LSTM model
embedding_dim = 100
lstm_units = 64
num_classes = 2

model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=embedding_dim, input_length=max_sequence_length))
model.add(LSTM(units=lstm_units))
model.add(Dense(units=num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train_pad, y_train, epochs=10, batch_size=64, validation_split=0.2)

loss, accuracy = model.evaluate(X_test_pad, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/10
# 78/78 [==============================] - 14s 144ms/step - loss: 0.5850 - accuracy: 0.6705 - val_loss: 0.4292 - val_accuracy: 0.8103
# Epoch 2/10
# 78/78 [==============================] - 11s 136ms/step - loss: 0.3267 - accuracy: 0.8672 - val_loss: 0.4702 - val_accuracy: 0.7805
# Epoch 3/10
# 78/78 [==============================] - 11s 137ms/step - loss: 0.2005 - accuracy: 0.9233 - val_loss: 0.5339 - val_accuracy: 0.7789
# Epoch 4/10
# 78/78 [==============================] - 9s 114ms/step - loss: 0.1097 - accuracy: 0.9637 - val_loss: 0.6963 - val_accuracy: 0.7603
# Epoch 5/10
# 78/78 [==============================] - 11s 142ms/step - loss: 0.0655 - accuracy: 0.9790 - val_loss: 0.7878 - val_accuracy: 0.7450
# Epoch 6/10
# 78/78 [==============================] - 11s 140ms/step - loss: 0.0543 - accuracy: 0.9838 - val_loss: 0.8898 - val_accuracy: 0.7264
# Epoch 7/10
# 78/78 [==============================] - 11s 137ms/step - loss: 0.0397 - accuracy: 0.9907 - val_loss: 1.0547 - val_accuracy: 0.7563
# Epoch 8/10
# 78/78 [==============================] - 9s 115ms/step - loss: 0.0210 - accuracy: 0.9952 - val_loss: 1.2593 - val_accuracy: 0.7450
# Epoch 9/10
# 78/78 [==============================] - 11s 142ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 1.1514 - val_accuracy: 0.7393
# Epoch 10/10
# 78/78 [==============================] - 11s 138ms/step - loss: 0.0150 - accuracy: 0.9943 - val_loss: 1.2891 - val_accuracy: 0.7450
# 33/33 [==============================] - 1s 16ms/step - loss: 1.4437 - accuracy: 0.7200
# Test Loss: 1.4437007904052734
# Test Accuracy: 0.7199612259864807

# %%
y_pred_probs = model.predict(X_test_pad)

y_pred = [1 if prob[1] > 0.5 else 0 for prob in y_pred_probs]
# Out:
# 33/33 [==============================] - 1s 15ms/step

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.63      0.69       502
#            1       0.70      0.80      0.75       530
#
#     accuracy                           0.72      1032
#    macro avg       0.73      0.72      0.72      1032
# weighted avg       0.72      0.72      0.72      1032

# %%
import pandas as pd
df = pd.DataFrame() # Initialize an empty DataFrame

# %%
y_pred_labels = ['hope' if pred == 1 else 'non hope' for pred in y_pred]
if 'PID' in df.index:
    predictions_df = pd.DataFrame({'ID': df.loc[y_test.index, 'PID'].values, 'category': y_pred_labels})
else:
     predictions_df = pd.DataFrame({'ID': range(len(y_pred_labels)), 'category': y_pred_labels})

predictions_df.to_csv('predictions11.csv', index=False)

print("Predictions saved to 'predictions11.csv'")
# Out:
# Predictions saved to 'predictions11.csv'

# %%
# !pip install sklearn
from sklearn.svm import SVC
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install ktrain
# Out:
# Collecting ktrain
#   Downloading ktrain-0.41.3.tar.gz (25.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.3/25.3 MB 19.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (3.7.1)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.0.3)
# Requirement already satisfied: fastprogress>=0.1.21 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ktrain) (24.0)
# Collecting langdetect (from ktrain)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 24.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.42.1)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.10/dist-packages (from ktrain) (3.3.2)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from ktrain) (5.2.0)
# Collecting syntok>1.3.3 (from ktrain)
#   Downloading syntok-1.4.4-py3-none-any.whl (24 kB)
# Collecting tika (from ktrain)
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from ktrain) (4.38.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.1.99)
# Collecting keras_bert>=0.86.0 (from ktrain)
#   Downloading keras-bert-0.89.0.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting whoosh (from ktrain)
#   Downloading Whoosh-2.7.4-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.8/468.8 kB 20.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras_bert>=0.86.0->ktrain) (1.25.2)
# Collecting keras-transformer==0.40.0 (from keras_bert>=0.86.0->ktrain)
#   Downloading keras-transformer-0.40.0.tar.gz (9.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-pos-embd==0.13.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-pos-embd-0.13.0.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-multi-head==0.29.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-layer-normalization==0.16.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-layer-normalization-0.16.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-position-wise-feed-forward==0.8.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-position-wise-feed-forward-0.8.0.tar.gz (4.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-embed-sim==0.10.0 (from keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-embed-sim-0.10.0.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting keras-self-attention==0.51.0 (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras_bert>=0.86.0->ktrain)
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->ktrain) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->ktrain) (2024.1)
# Requirement already satisfied: regex>2016 in /usr/local/lib/python3.10/dist-packages (from syntok>1.3.3->ktrain) (2023.12.25)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (2024.2.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (3.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika->ktrain) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers->ktrain) (3.13.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers->ktrain) (0.20.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers->ktrain) (6.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->ktrain) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->ktrain) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->ktrain) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers->ktrain) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers->ktrain) (4.11.0)
# Building wheels for collected packages: ktrain, keras_bert, keras-transformer, keras-embed-sim, keras-layer-normalization, keras-multi-head, keras-pos-embd, keras-position-wise-feed-forward, keras-self-attention, langdetect, tika
#   Building wheel for ktrain (setup.py) ... done
#   Created wheel for ktrain: filename=ktrain-0.41.3-py3-none-any.whl size=25316960 sha256=df3f9a910674252bd6474e8e22a4bf09fd443e047a2f03257d6b6c80d6230aa7
#   Stored in directory: /root/.cache/pip/wheels/fc/76/11/5b953090eebf531f660948a30cd26e70260619f6480f186a5a
#   Building wheel for keras_bert (setup.py) ... done
#   Created wheel for keras_bert: filename=keras_bert-0.89.0-py3-none-any.whl size=33500 sha256=771d1cfdfbca89e59a08a30c26fcb1d77aaa01fa99bd13714325bba6b1fad77a
#   Stored in directory: /root/.cache/pip/wheels/89/0c/04/646b6fdf6375911b42c8d540a8a3fda8d5d77634e5dcbe7b26
#   Building wheel for keras-transformer (setup.py) ... done
#   Created wheel for keras-transformer: filename=keras_transformer-0.40.0-py3-none-any.whl size=12286 sha256=e7a92a78ed176e8c53b4c79595b838969b7ded08b46ef8298f4f374f237dfa46
#   Stored in directory: /root/.cache/pip/wheels/f2/cb/22/75a0ad376129177f7c95c0d91331a18f5368fd657f4035ba7c
#   Building wheel for keras-embed-sim (setup.py) ... done
#   Created wheel for keras-embed-sim: filename=keras_embed_sim-0.10.0-py3-none-any.whl size=3944 sha256=faf47d483989a30fc3d614aa1df445cddff3081fd2cd7089dd8ca7167f9c1458
#   Stored in directory: /root/.cache/pip/wheels/82/32/c7/fd35d0d1b840a6c7cbd4343f808d10d0f7b87d271a4dbe796f
#   Building wheel for keras-layer-normalization (setup.py) ... done
#   Created wheel for keras-layer-normalization: filename=keras_layer_normalization-0.16.0-py3-none-any.whl size=4654 sha256=0a575c326458d7e24173e4aa3642b894b5d7076b64eb606de92bd24697781280
#   Stored in directory: /root/.cache/pip/wheels/ed/3a/4b/21db23c0cc56c4b219616e181f258eb7c57d36cc5d056fae9a
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14976 sha256=27f3783d074e981bd135fa8102712769d4d8be18e9b9ce801d46cca1598667b0
#   Stored in directory: /root/.cache/pip/wheels/cb/23/4b/06d7ae21714f70fcc25b48f972cc8e5e7f4b6b764a038b509d
#   Building wheel for keras-pos-embd (setup.py) ... done
#   Created wheel for keras-pos-embd: filename=keras_pos_embd-0.13.0-py3-none-any.whl size=6945 sha256=cfedd3024d508c9ca5e6f467450d9a7ef7446dfcabf5deb9f8a0260795f495d0
#   Stored in directory: /root/.cache/pip/wheels/78/07/1b/b1ca47b6ac338554b75c8f52c54e6a2bfbe1b07d79579979a4
#   Building wheel for keras-position-wise-feed-forward (setup.py) ... done
#   Created wheel for keras-position-wise-feed-forward: filename=keras_position_wise_feed_forward-0.8.0-py3-none-any.whl size=4969 sha256=df47018e8b7e6e28df095c2c96194c066d413f0ee1b3006c438cef2e3ce8fcca
#   Stored in directory: /root/.cache/pip/wheels/c1/6a/04/d1706a53b23b2cb5f9a0a76269bf87925daa1bca09eac01b21
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18894 sha256=9e8fb397cfa321c7db7988d7f831047e2dc838ce9768917f37c80f282f0a91ba
#   Stored in directory: /root/.cache/pip/wheels/b8/f7/24/607b483144fb9c47b4ba2c5fba6b68e54aeee2d5bf6c05302e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=7c7a51201255a92201bad9ae612079cae524df172c49a84e3176c092ef0c22a2
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32621 sha256=2d172311326016a5fde3390e2c98c2fb617d3809b9e9721b55bd405b6b1d8ab2
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built ktrain keras_bert keras-transformer keras-embed-sim keras-layer-normalization keras-multi-head keras-pos-embd keras-position-wise-feed-forward keras-self-attention langdetect tika
# Installing collected packages: whoosh, syntok, langdetect, keras-self-attention, keras-position-wise-feed-forward, keras-pos-embd, keras-layer-normalization, keras-embed-sim, tika, keras-multi-head, keras-transformer, keras_bert, ktrain
# Successfully installed keras-embed-sim-0.10.0 keras-layer-normalization-0.16.0 keras-multi-head-0.29.0 keras-pos-embd-0.13.0 keras-position-wise-feed-forward-0.8.0 keras-self-attention-0.51.0 keras-transformer-0.40.0 keras_bert-0.89.0 ktrain-0.41.3 langdetect-1.0.9 syntok-1.4.4 tika-2.6.0 whoosh-2.7.4

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import ktrain
from ktrain import text
import pandas as pd
import ktrain
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %%
from sklearn.model_selection import train_test_split

X_train= dftrain["text"].values
y_train= dftrain["label"].values


X_val= dfvalid["text"].values
y_val= dfvalid["label"].values

# %%
model = Sequential()
model.add(Dense(128, input_shape=(28, 28), activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
import ktrain
import numpy as np

train_data = (X_train, y_train)
val_data = (X_val, y_val)
learner = ktrain.get_learner(model, train_data=train_data, val_data=val_data, batch_size=12)

# %%
import tensorflow as tf
#model = t.get_classifier(optimizer='adam')
learner = ktrain.get_learner(model, train_data=X_train, val_data=X_val, batch_size=12)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-d9da460b92f4> in <cell line: 3>()
#       1 import tensorflow as tf
#       2 #model = t.get_classifier(optimizer='adam')
# ----> 3 learner = ktrain.get_learner(model, train_data=X_train, val_data=X_val, batch_size=12)
#
# /usr/local/lib/python3.10/dist-packages/ktrain/__init__.py in get_learner(model, train_data, val_data, batch_size, eval_batch_size, workers, use_multiprocessing)
#      57     if not isinstance(model, I.keras.Model):
#      58         raise ValueError("model must be of instance Model")
# ---> 59     U.data_arg_check(train_data=train_data, val_data=val_data)
#      60     if type(workers) != type(1) or workers < 1:
#      61         workers = 1
#
# /usr/local/lib/python3.10/dist-packages/ktrain/utils.py in data_arg_check(train_data, val_data, train_required, val_required, ndarray_only)
#     423             if not ndarray_only:
#     424                 err_msg += " or an instance of ktrain.Dataset"
# --> 425             raise ValueError(err_msg)
#     426     if val_data is not None and not is_iter(val_data, ndarray_only):
#     427         if bad_data_tuple(val_data):
#
# ValueError: data must be tuple of numpy.ndarrays or an instance of ktrain.Dataset

# %%
MODEL_NAME = 'google-bert/bert-base-multilingual-uncased'

t = text.Transformer(MODEL_NAME, maxlen=400, classes=np.array([0,1]))
trn = t.preprocess_train(np.array(X_train),np.array(y_train))
val = t.preprocess_test(np.array(X_val), np.array(y_val))
model = t.get_classifier()
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=12)
# Out:
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 32
# 	95percentile : 53
# 	99percentile : 58
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 31
# 	95percentile : 53
# 	99percentile : 57
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-dc45a8e9d69e> in <cell line: 6>()
#       4 trn = t.preprocess_train(np.array(X_train),np.array(y_train))
#       5 val = t.preprocess_test(np.array(X_val), np.array(y_val))
# ----> 6 model = t.get_classifier()
#       7 learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=12)
#
# /usr/local/lib/python3.10/dist-packages/ktrain/text/preprocessor.py in get_classifier(self, fpath, multilabel, metrics)
#    1160         else:
#    1161             loss_fn = keras.losses.CategoricalCrossentropy(from_logits=True)
# -> 1162         model.compile(loss=loss_fn, optimizer=U.DEFAULT_OPT, metrics=metrics)
#    1163         return model
#    1164
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_tf_utils.py in compile(self, optimizer, loss, metrics, loss_weights, weighted_metrics, run_eagerly, steps_per_execution, **kwargs)
#    1493         # This argument got renamed, we need to support both versions
#    1494         if "steps_per_execution" in parent_args:
# -> 1495             super().compile(
#    1496                 optimizer=optimizer,
#    1497                 loss=loss,
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/optimizers/__init__.py in get(identifier, **kwargs)
#     332         )
#     333     else:
# --> 334         raise ValueError(
#     335             f"Could not interpret optimizer identifier: {identifier}"
#     336         )
#
# ValueError: Could not interpret optimizer identifier: <keras.src.optimizers.legacy.adam.Adam object at 0x7f9120add3f0>

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=3e-5)
MODEL_NAME = 'google-bert/bert-base-multilingual-uncased'
t = text.Transformer(MODEL_NAME, maxlen=400, classes=np.array([0,1]))
trn = t.preprocess_train(np.array(X_train),np.array(y_train))
val = t.preprocess_test(np.array(X_val), np.array(y_val))
model = t.get_classifier()
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
learner = ktrain.get_learner(model, train_data=trn, val_data=val, batch_size=12)
# Out:
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 32
# 	95percentile : 53
# 	99percentile : 58
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 31
# 	95percentile : 53
# 	99percentile : 57
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-e948a3a9457f> in <cell line: 13>()
#      11
#      12 # Define the model
# ---> 13 model = t.get_classifier()
#      14
#      15 # Compile the model with the specified optimizer
#
# /usr/local/lib/python3.10/dist-packages/ktrain/text/preprocessor.py in get_classifier(self, fpath, multilabel, metrics)
#    1160         else:
#    1161             loss_fn = keras.losses.CategoricalCrossentropy(from_logits=True)
# -> 1162         model.compile(loss=loss_fn, optimizer=U.DEFAULT_OPT, metrics=metrics)
#    1163         return model
#    1164
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_tf_utils.py in compile(self, optimizer, loss, metrics, loss_weights, weighted_metrics, run_eagerly, steps_per_execution, **kwargs)
#    1493         # This argument got renamed, we need to support both versions
#    1494         if "steps_per_execution" in parent_args:
# -> 1495             super().compile(
#    1496                 optimizer=optimizer,
#    1497                 loss=loss,
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tf_keras/src/optimizers/__init__.py in get(identifier, **kwargs)
#     332         )
#     333     else:
# --> 334         raise ValueError(
#     335             f"Could not interpret optimizer identifier: {identifier}"
#     336         )
#
# ValueError: Could not interpret optimizer identifier: <keras.src.optimizers.legacy.adam.Adam object at 0x7f9120add3f0>

# %%
learner.fit_onecycle(1e-5, 3)

# %%
pred = ktrain.get_predictor(learner.model,preproc = t)

# %%
predictor_1=pred.predict(X_val)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
print(classification_report(y_val,predictor_1))
print(accuracy_score(y_val, predictor_1))
